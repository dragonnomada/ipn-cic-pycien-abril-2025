# %%
import pandas

titanic = pandas.read_csv("../datasets/titanic.csv")

titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
survived = titanic["Survived"]

survived.describe()
# Out:
# count    891.000000
# mean       0.383838
# std        0.486592
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: Survived, dtype: float64

# %%
import seaborn

seaborn.histplot(titanic, x="Pclass", hue="Survived", discrete=True)
# Out:
# <Axes: xlabel='Pclass', ylabel='Count'>

# %%
seaborn.barplot(titanic, y="Survived", hue="Pclass")
# Out:
# <Axes: ylabel='Survived'>

# %%
seaborn.violinplot(titanic, y="Pclass", hue="Survived")
# Out:
# <Axes: ylabel='Pclass'>

# %%
seaborn.violinplot(titanic, y="Survived", hue="Pclass")
# Out:
# <Axes: ylabel='Survived'>

# %%
data1 = titanic[["Sex", "Survived"]]

data1
# Out:
#         Sex  Survived
# 0      male         0
# 1    female         1
# 2    female         1
# 3    female         1
# 4      male         0
# ..      ...       ...
# 886    male         0
# 887  female         1
# 888  female         0
# 889    male         1
# 890    male         0
#
# [891 rows x 2 columns]

# %%
report1 = data1.groupby("Sex").aggregate("mean")
report1
# Out:
#         Survived
# Sex
# female  0.742038
# male    0.188908

# %%
seaborn.countplot(report1)
# Out:
# <Axes: ylabel='count'>

# %%
import scipy.stats as stats

x1 = titanic[(titanic["Sex"] == "male") & (titanic["Pclass"] == 1)]["Survived"]
x2 = titanic[(titanic["Sex"] == "male") & (titanic["Pclass"] == 3)]["Survived"]

t_stat, p_val = stats.ttest_ind(x1, x2)

print(f"T-Test: {t_stat:.2f}, Valor-P: {p_val:.2f}")
# Out:
# T-Test: 5.77, Valor-P: 0.00
